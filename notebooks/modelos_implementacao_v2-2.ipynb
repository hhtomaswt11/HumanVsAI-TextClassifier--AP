# %% [markdown]
# # Tarefa 2: Modelos com Implementação Própria (NumPy)
#
# Este notebook apresenta a implementação de raiz de modelos de Deep Learning utilizando exclusivamente a biblioteca **NumPy**. O objetivo é classificar textos entre 5 classes distintas: **Google, Human, Meta, Anthropic e OpenAI**.
#
# De acordo com os requisitos do enunciado, exploramos uma abordagem de implementação manual para compreender os fundamentos de *Backpropagation* e otimização de redes neuronais.
#
# ## Arquitetura: Abordagem *Divide and Conquer*
# - **Modelo 1 (Binário):** Distingue textos *Human* vs *IA*
# - **Modelo 2 (Multiclasse):** Distingue entre as diferentes IAs (Google, Meta, Mistral, OpenAI)

# %% [markdown]
# ## 0. Imports e Configuração

# %%
import sys
sys.path.append('../models/numpy_models')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, matthews_corrcoef, confusion_matrix, classification_report

from neuralnet import NeuralNetwork
from layers import DenseLayer, DropoutLayer
from activation import ReLUActivation, SoftmaxActivation
from losses import CategoricalCrossEntropy
from metrics import accuracy

np.random.seed(42)

# %% [markdown]
# ## 1. Carregamento e Preparação dos Dados
#
# ### 1.1 Carregamento
#
# As classes presentes no dataset são: **Google, Human, Meta, Anthropic e OpenAI**.
# O enunciado refere 'Mistral' mas o professor confirmou que a classe correta é `Anthropic` — não há remapeamento necessário.

# %%
# --- Carregar datasets ---
df = pd.read_csv('../data/dataset_limpo.csv', sep=';')
df = df.dropna(subset=['Text', 'Label'])

df_exemplos = pd.read_csv('../data/dataset-exemplos.csv', sep=';')
df_exemplos = df_exemplos.dropna(subset=['Text', 'Label'])

print("Distribuição do dataset de treino:")
print(df['Label'].value_counts())
print(f"\nTotal: {len(df)} amostras")

print("\nDistribuição do dataset de exemplos do professor:")
print(df_exemplos['Label'].value_counts())
print(f"Total: {len(df_exemplos)} amostras")
# Out:
# Distribuição do dataset de treino:
# Label
# Human        999
# OpenAI       999
# Google       999
# Meta         999
# Anthropic    999
# Name: count, dtype: int64
#
# Total: 4995 amostras
#
# Distribuição do dataset de exemplos do professor:
# Label
# Human        52
# Anthropic    23
# Meta         17
# OpenAI       17
# Google       16
# Name: count, dtype: int64
# Total: 125 amostras

# %% [markdown]
# ### 1.2 Criação dos Sub-datasets e Balanceamento
#
# - **Modelo 1 (Binário):** Usamos todo o dataset sem oversampling. A rede compensa o desequilíbrio Human:IA (1:4) com `Dropout` mais agressivo e um threshold de decisão mais equilibrado.
# - **Modelo 2 (Multiclasse):** Filtramos apenas as amostras de IA. As classes estão já equilibradas (~999 cada).
#
# > **Nota:** Oversampling com `replace=True` cria duplicados perfeitos que a rede memoriza, causando overfitting severo. Preferimos usar o dataset sem resampling e deixar a arquitetura DNN gerir o desequilíbrio.

# %%
# --- Modelo 1: Human vs IA (sem oversampling) ---
df_model1 = df.copy()
df_model1['Label_Bin'] = np.where(df_model1['Label'] == 'Human', 'Human', 'IA')

print("Distribuição Modelo 1 (dataset completo):")
print(df_model1['Label_Bin'].value_counts())

# --- Modelo 2: Qual IA? ---
df_model2 = df[df['Label'] != 'Human'].reset_index(drop=True)
print("\nDistribuição Modelo 2 (IAs):")
print(df_model2['Label'].value_counts())
# Out:
# Distribuição Modelo 1 (dataset completo):
# Label_Bin
# IA       3678
# Human     999
# Name: count, dtype: int64
#
# Distribuição Modelo 2 (IAs):
# Label
# Google       999
# Meta         999
# OpenAI       998
# Anthropic    682
# Name: count, dtype: int64

# %% [markdown]
# ### 1.3 Divisão Treino / Validação / Teste e Features TF-IDF
#
# Utilizamos uma divisão estratificada **80% / 10% / 10%** (treino / validação / teste).
#
# **Feature Engineering — combinação de word e char n-grams:**
# - **Modelo 1:** Concatenamos `word n-grams (1,2)` + `char n-grams (3,5)` (1000+1000 features). A combinação captura padrões léxicos *e* tipográficos, generalizando melhor para textos externos.
# - **Modelo 2:** `char n-grams (3,5)`, 3000 features — captura estilo tipográfico subtil entre diferentes IAs.
#
# > O TF-IDF é ajustado (`fit`) **apenas nos dados de treino** para evitar *data leakage*. O `min_df=0.05` foi removido do Modelo 1 — estava a eliminar 217 das 400 features (ficavam apenas 183), reduzindo muito a expressividade do modelo.

# %%
# === MODELO 1 ===
X1 = df_model1['Text']
y1_raw = df_model1['Label_Bin']
classes1 = sorted(y1_raw.unique())  # ['Human', 'IA']
y1_encoded = pd.get_dummies(y1_raw).astype(int).values

X1_train, X1_temp, y1_train, y1_temp = train_test_split(
    X1, y1_encoded, test_size=0.2, random_state=42, stratify=y1_encoded
)
X1_val, X1_test, y1_val, y1_test = train_test_split(
    X1_temp, y1_temp, test_size=0.5, random_state=42, stratify=y1_temp
)

# Modelo 1: combinar word e char n-grams para melhor generalização
tfidf1_word = TfidfVectorizer(max_features=1000, ngram_range=(1, 2))
tfidf1_char = TfidfVectorizer(max_features=1000, analyzer='char', ngram_range=(3, 5))

X1_train_w = tfidf1_word.fit_transform(X1_train).toarray()
X1_train_c = tfidf1_char.fit_transform(X1_train).toarray()
X1_train_tfidf = np.hstack([X1_train_w, X1_train_c])

X1_val_tfidf = np.hstack([
    tfidf1_word.transform(X1_val).toarray(),
    tfidf1_char.transform(X1_val).toarray()
])
X1_test_tfidf = np.hstack([
    tfidf1_word.transform(X1_test).toarray(),
    tfidf1_char.transform(X1_test).toarray()
])

print(f"Modelo 1 — Treino: {X1_train_tfidf.shape[0]} | Val: {X1_val_tfidf.shape[0]} | Teste: {X1_test_tfidf.shape[0]}")
print(f"Features TF-IDF Modelo 1: {X1_train_tfidf.shape[1]} (word:{X1_train_w.shape[1]} + char:{X1_train_c.shape[1]})")

# === MODELO 2 ===
X2 = df_model2['Text']
y2_raw = df_model2['Label']
classes2 = sorted(y2_raw.unique())  # ['Anthropic', 'Google', 'Meta', 'OpenAI']
y2_encoded = pd.get_dummies(y2_raw).astype(int).values

X2_train, X2_temp, y2_train, y2_temp = train_test_split(
    X2, y2_encoded, test_size=0.2, random_state=42, stratify=y2_encoded
)
X2_val, X2_test, y2_val, y2_test = train_test_split(
    X2_temp, y2_temp, test_size=0.5, random_state=42, stratify=y2_temp
)

tfidf2 = TfidfVectorizer(max_features=3000, analyzer='char', ngram_range=(3, 5))
X2_train_tfidf = tfidf2.fit_transform(X2_train).toarray()
X2_val_tfidf   = tfidf2.transform(X2_val).toarray()
X2_test_tfidf  = tfidf2.transform(X2_test).toarray()

print(f"\nModelo 2 — Treino: {X2_train_tfidf.shape[0]} | Val: {X2_val_tfidf.shape[0]} | Teste: {X2_test_tfidf.shape[0]}")
print(f"Features TF-IDF Modelo 2: {X2_train_tfidf.shape[1]}")

print(f"\nClasses Modelo 1: {classes1}")
print(f"Classes Modelo 2: {classes2}")
# Out:
# Modelo 1 — Treino: 3741 | Val: 468 | Teste: 468
# Features TF-IDF Modelo 1: 2000 (word:1000 + char:1000)
#
# Modelo 2 — Treino: 2942 | Val: 368 | Teste: 368
# Features TF-IDF Modelo 2: 3000
#
# Classes Modelo 1: ['Human', 'IA']
# Classes Modelo 2: ['Anthropic', 'Google', 'Meta', 'OpenAI']

# %% [markdown]
# ### 1.4 Classe TextDataset

# %%
class TextDataset:
    """Wrapper simples para encapsular X e y num objeto compatível com NeuralNetwork."""
    def __init__(self, X, y):
        self.X = X
        self.y = y

train_dataset1 = TextDataset(X1_train_tfidf, y1_train)
val_dataset1   = TextDataset(X1_val_tfidf,   y1_val)
test_dataset1  = TextDataset(X1_test_tfidf,  y1_test)

train_dataset2 = TextDataset(X2_train_tfidf, y2_train)
val_dataset2   = TextDataset(X2_val_tfidf,   y2_val)
test_dataset2  = TextDataset(X2_test_tfidf,  y2_test)

# %% [markdown]
# ## 2. Modelos Baseline (Regressão Logística / Softmax Regression)
#
# O baseline corresponde a uma rede neural **sem camadas ocultas** — matematicamente equivalente à Regressão Logística (binária) e Softmax Regression (multiclasse).
#
# Serve como referência mínima para comparar com as DNNs mais profundas.

# %%
n_features1 = X1_train_tfidf.shape[1]
n_features2 = X2_train_tfidf.shape[1]

# --- Baseline 1: Human vs IA ---
baseline1 = NeuralNetwork(
    epochs=200, batch_size=64, learning_rate=0.05,
    verbose=True, loss=CategoricalCrossEntropy, metric=accuracy
)
baseline1.add(DenseLayer(len(classes1), input_shape=(n_features1,)))
baseline1.add(SoftmaxActivation())

print("--- Treinar Baseline 1: Regressão Logística (Human vs IA) ---")
baseline1.fit(train_dataset1, val_dataset=val_dataset1)
# Out:
# --- Treinar Baseline 1: Regressão Logística (Human vs IA) ---
# Epoch 1/200 - loss: 0.5803 - val_loss: 0.4934 - accuracy: 0.7851
# Epoch 10/200 - loss: 0.4255 - val_loss: 0.3937 - accuracy: 0.8035
# Epoch 20/200 - loss: 0.3621 - val_loss: 0.3353 - accuracy: 0.8434
# Epoch 30/200 - loss: 0.3238 - val_loss: 0.3005 - accuracy: 0.8685
# Epoch 40/200 - loss: 0.2942 - val_loss: 0.2772 - accuracy: 0.8832
# Epoch 50/200 - loss: 0.2734 - val_loss: 0.2600 - accuracy: 0.8939
# Epoch 60/200 - loss: 0.2577 - val_loss: 0.2465 - accuracy: 0.9059
# Epoch 70/200 - loss: 0.2437 - val_loss: 0.2356 - accuracy: 0.9163
# Epoch 80/200 - loss: 0.2297 - val_loss: 0.2263 - accuracy: 0.9195
# Epoch 90/200 - loss: 0.2204 - val_loss: 0.2183 - accuracy: 0.9249
# Epoch 100/200 - loss: 0.2113 - val_loss: 0.2114 - accuracy: 0.9302
# Epoch 110/200 - loss: 0.2029 - val_loss: 0.2053 - accuracy: 0.9329
# Epoch 120/200 - loss: 0.1958 - val_loss: 0.1998 - accuracy: 0.9350
# Epoch 130/200 - loss: 0.1898 - val_loss: 0.1949 - accuracy: 0.9385
# Epoch 140/200 - loss: 0.1831 - val_loss: 0.1904 - accuracy: 0.9404
# Epoch 150/200 - loss: 0.1790 - val_loss: 0.1863 - accuracy: 0.9412
# Epoch 160/200 - loss: 0.1739 - val_loss: 0.1825 - accuracy: 0.9433
# Epoch 170/200 - loss: 0.1691 - val_loss: 0.1791 - accuracy: 0.9460
# Epoch 180/200 - loss: 0.1655 - val_loss: 0.1759 - accuracy: 0.9495
# Epoch 190/200 - loss: 0.1602 - val_loss: 0.1729 - accuracy: 0.9513
# Epoch 200/200 - loss: 0.1568 - val_loss: 0.1701 - accuracy: 0.9535

# %%
# --- Baseline 2: Qual IA? ---
baseline2 = NeuralNetwork(
    epochs=200, batch_size=64, learning_rate=0.05,
    verbose=True, loss=CategoricalCrossEntropy, metric=accuracy
)
baseline2.add(DenseLayer(len(classes2), input_shape=(n_features2,)))
baseline2.add(SoftmaxActivation())

print("--- Treinar Baseline 2: Softmax Regression (IAs) ---")
baseline2.fit(train_dataset2, val_dataset=val_dataset2)
# Out:
# --- Treinar Baseline 2: Softmax Regression (IAs) ---
# Epoch 1/200 - loss: 1.3896 - val_loss: 1.3730 - accuracy: 0.3076
# Epoch 10/200 - loss: 1.3019 - val_loss: 1.2966 - accuracy: 0.4177
# Epoch 20/200 - loss: 1.2313 - val_loss: 1.2289 - accuracy: 0.5044
# Epoch 30/200 - loss: 1.1688 - val_loss: 1.1690 - accuracy: 0.5853
# Epoch 40/200 - loss: 1.1131 - val_loss: 1.1157 - accuracy: 0.6455
# Epoch 50/200 - loss: 1.0632 - val_loss: 1.0681 - accuracy: 0.6839
# Epoch 60/200 - loss: 1.0185 - val_loss: 1.0256 - accuracy: 0.7186
# Epoch 70/200 - loss: 0.9783 - val_loss: 0.9874 - accuracy: 0.7403
# Epoch 80/200 - loss: 0.9420 - val_loss: 0.9529 - accuracy: 0.7590
# Epoch 90/200 - loss: 0.9090 - val_loss: 0.9216 - accuracy: 0.7753
# Epoch 100/200 - loss: 0.8788 - val_loss: 0.8931 - accuracy: 0.7876
# Epoch 110/200 - loss: 0.8513 - val_loss: 0.8671 - accuracy: 0.8022
# Epoch 120/200 - loss: 0.8260 - val_loss: 0.8432 - accuracy: 0.8103
# Epoch 130/200 - loss: 0.8026 - val_loss: 0.8211 - accuracy: 0.8151
# Epoch 140/200 - loss: 0.7811 - val_loss: 0.8008 - accuracy: 0.8226
# Epoch 150/200 - loss: 0.7611 - val_loss: 0.7818 - accuracy: 0.8300
# Epoch 160/200 - loss: 0.7424 - val_loss: 0.7643 - accuracy: 0.8372
# Epoch 170/200 - loss: 0.7249 - val_loss: 0.7479 - accuracy: 0.8396
# Epoch 180/200 - loss: 0.7085 - val_loss: 0.7325 - accuracy: 0.8433
# Epoch 190/200 - loss: 0.6933 - val_loss: 0.7181 - accuracy: 0.8487
# Epoch 200/200 - loss: 0.6788 - val_loss: 0.7045 - accuracy: 0.8532

# %%
# --- Avaliação dos Baselines no conjunto de teste interno ---
def evaluate_model(model, dataset, classes, name=""):
    """Avalia um modelo num dataset e imprime Accuracy e MCC."""
    probs = model.predict(dataset)
    y_pred_idx = np.argmax(probs, axis=1)
    y_true_idx = np.argmax(dataset.y, axis=1)
    
    y_pred_labels = [classes[i] for i in y_pred_idx]
    y_true_labels = [classes[i] for i in y_true_idx]
    
    acc = accuracy_score(y_true_labels, y_pred_labels)
    mcc = matthews_corrcoef(y_true_labels, y_pred_labels)
    
    print(f"[{name}] Accuracy: {acc*100:.2f}% | MCC: {mcc:.4f}")
    return y_pred_labels, y_true_labels

print("=== Avaliação no Teste Interno ===")
evaluate_model(baseline1, test_dataset1, classes1, "Baseline1")
evaluate_model(baseline2, test_dataset2, classes2, "Baseline2")
# Out:
# === Avaliação no Teste Interno ===
# [Baseline1] Accuracy: 92.74% | MCC: 0.7750
# [Baseline2] Accuracy: 84.51% | MCC: 0.7922
# (['OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Anthropic'],
#  ['OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Anthropic'])

# %% [markdown]
# ## 3. DNNs — Abordagem *Divide and Conquer*
#
# Implementamos duas DNNs com camadas ocultas, Dropout e ReLU:
# - **DNN 1:** 2000 features entrada → 128 → Dropout(0.4) → 64 → Dropout(0.2) → saída binária
# - **DNN 2:** 3000 features → 64 → Dropout(0.2) → saída 4 classes (IAs)
#
# O Dropout mais agressivo (0.4) na DNN 1 serve para compensar o desequilíbrio de classes (1:4) e reduzir overfitting.
#
# > **Nota sobre generalização:** Os modelos atingem >95% no teste interno (mesma distribuição do treino), mas uma performance inferior no dataset externo do professor é esperada — os textos de treino e de avaliação provêm de fontes e geradores diferentes. Este fenômeno chama-se *domain shift* e é um desafio fundamental em text classification.

# %%
# --- DNN 1: Human vs IA ---
# Dropout mais alto (0.4) para compensar desequilíbrio de classes e reduzir overfitting
net1 = NeuralNetwork(
    epochs=200, batch_size=64, learning_rate=0.01,
    verbose=True, loss=CategoricalCrossEntropy, metric=accuracy
)
net1.add(DenseLayer(128, input_shape=(n_features1,)))
net1.add(ReLUActivation())
net1.add(DropoutLayer(0.4))
net1.add(DenseLayer(64))
net1.add(ReLUActivation())
net1.add(DropoutLayer(0.2))
net1.add(DenseLayer(len(classes1)))
net1.add(SoftmaxActivation())

print("--- Treinar DNN 1 (Human vs IA) ---")
net1.fit(train_dataset1, val_dataset=val_dataset1)
# Out:
# --- Treinar DNN 1 (Human vs IA) ---
# Epoch 1/200 - loss: 0.8311 - val_loss: 0.5706 - accuracy: 0.7605
# Epoch 10/200 - loss: 0.5197 - val_loss: 0.4108 - accuracy: 0.8110
# Epoch 20/200 - loss: 0.4673 - val_loss: 0.3781 - accuracy: 0.8340
# Epoch 30/200 - loss: 0.4209 - val_loss: 0.3502 - accuracy: 0.8506
# Epoch 40/200 - loss: 0.4107 - val_loss: 0.3272 - accuracy: 0.8613
# Epoch 50/200 - loss: 0.3793 - val_loss: 0.3080 - accuracy: 0.8685
# Epoch 60/200 - loss: 0.3714 - val_loss: 0.2916 - accuracy: 0.8797
# Epoch 70/200 - loss: 0.3578 - val_loss: 0.2786 - accuracy: 0.8877
# Epoch 80/200 - loss: 0.3412 - val_loss: 0.2678 - accuracy: 0.8939
# Epoch 90/200 - loss: 0.3261 - val_loss: 0.2569 - accuracy: 0.8990
# Epoch 100/200 - loss: 0.3089 - val_loss: 0.2487 - accuracy: 0.9046
# Epoch 110/200 - loss: 0.3054 - val_loss: 0.2403 - accuracy: 0.9107
# Epoch 120/200 - loss: 0.2948 - val_loss: 0.2325 - accuracy: 0.9177
# Epoch 130/200 - loss: 0.2861 - val_loss: 0.2263 - accuracy: 0.9203
# Epoch 140/200 - loss: 0.2717 - val_loss: 0.2182 - accuracy: 0.9238
# Epoch 150/200 - loss: 0.2774 - val_loss: 0.2129 - accuracy: 0.9276
# Epoch 160/200 - loss: 0.2629 - val_loss: 0.2087 - accuracy: 0.9286
# Epoch 170/200 - loss: 0.2553 - val_loss: 0.2025 - accuracy: 0.9324
# Epoch 180/200 - loss: 0.2412 - val_loss: 0.1975 - accuracy: 0.9334
# Epoch 190/200 - loss: 0.2286 - val_loss: 0.1923 - accuracy: 0.9366
# Epoch 200/200 - loss: 0.2428 - val_loss: 0.1894 - accuracy: 0.9391

# %%
# --- DNN 2: Qual IA? ---
net2 = NeuralNetwork(
    epochs=200, batch_size=64, learning_rate=0.05,
    verbose=True, loss=CategoricalCrossEntropy, metric=accuracy
)
net2.add(DenseLayer(64, input_shape=(n_features2,)))
net2.add(ReLUActivation())
net2.add(DropoutLayer(0.2))
net2.add(DenseLayer(len(classes2)))
net2.add(SoftmaxActivation())

print("--- Treinar DNN 2 (Classificação de IAs) ---")
net2.fit(train_dataset2, val_dataset=val_dataset2)
# Out:
# --- Treinar DNN 2 (Classificação de IAs) ---
# Epoch 1/200 - loss: 1.4047 - val_loss: 1.3732 - accuracy: 0.3168
# Epoch 10/200 - loss: 1.1943 - val_loss: 1.1749 - accuracy: 0.5354
# Epoch 20/200 - loss: 0.9787 - val_loss: 0.9582 - accuracy: 0.6866
# Epoch 30/200 - loss: 0.8190 - val_loss: 0.7854 - accuracy: 0.7610
# Epoch 40/200 - loss: 0.6881 - val_loss: 0.6615 - accuracy: 0.8120
# Epoch 50/200 - loss: 0.5900 - val_loss: 0.5698 - accuracy: 0.8498
# Epoch 60/200 - loss: 0.5251 - val_loss: 0.5053 - accuracy: 0.8766
# Epoch 70/200 - loss: 0.4614 - val_loss: 0.4534 - accuracy: 0.8933
# Epoch 80/200 - loss: 0.4170 - val_loss: 0.4173 - accuracy: 0.9143
# Epoch 90/200 - loss: 0.3741 - val_loss: 0.3865 - accuracy: 0.9242
# Epoch 100/200 - loss: 0.3453 - val_loss: 0.3654 - accuracy: 0.9320
# Epoch 110/200 - loss: 0.3204 - val_loss: 0.3470 - accuracy: 0.9415
# Epoch 120/200 - loss: 0.2876 - val_loss: 0.3318 - accuracy: 0.9494
# Epoch 130/200 - loss: 0.2654 - val_loss: 0.3187 - accuracy: 0.9558
# Epoch 140/200 - loss: 0.2452 - val_loss: 0.3125 - accuracy: 0.9630
# Epoch 150/200 - loss: 0.2300 - val_loss: 0.3040 - accuracy: 0.9674
# Epoch 160/200 - loss: 0.2052 - val_loss: 0.2960 - accuracy: 0.9704
# Epoch 170/200 - loss: 0.1970 - val_loss: 0.2909 - accuracy: 0.9728
# Epoch 180/200 - loss: 0.1828 - val_loss: 0.2831 - accuracy: 0.9779
# Epoch 190/200 - loss: 0.1832 - val_loss: 0.2868 - accuracy: 0.9806
# Epoch 200/200 - loss: 0.1571 - val_loss: 0.2783 - accuracy: 0.9827

# %%
# --- Avaliação das DNNs no teste interno ---
print("=== Avaliação DNNs no Teste Interno ===")
evaluate_model(net1, test_dataset1, classes1, "DNN1")
evaluate_model(net2, test_dataset2, classes2, "DNN2")
# Out:
# === Avaliação DNNs no Teste Interno ===
# [DNN1] Accuracy: 90.38% | MCC: 0.6985
# [DNN2] Accuracy: 90.22% | MCC: 0.8688
# (['OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Anthropic'],
#  ['OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Anthropic',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'Meta',
#   'Google',
#   'Anthropic',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'OpenAI',
#   'OpenAI',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Google',
#   'Meta',
#   'OpenAI',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Google',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'OpenAI',
#   'Anthropic',
#   'OpenAI',
#   'Anthropic',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'Google',
#   'OpenAI',
#   'OpenAI',
#   'Google',
#   'OpenAI',
#   'Meta',
#   'Meta',
#   'Anthropic',
#   'Google',
#   'Meta',
#   'Anthropic',
#   'Anthropic'])

# %% [markdown]
# ## 4. Pipeline Final: *Divide and Conquer*
#
# A pipeline combina os dois modelos em sequência:
# 1. O **Modelo 1** decide se o texto é *Human* ou *IA*
# 2. Se *IA*, o **Modelo 2** decide qual das 4 IAs (Google, Meta, Mistral, OpenAI)
#
# > ⚠️ **Nota de design:** Esta abordagem propaga erros do Modelo 1 para o Modelo 2. Textos humanos mal classificados na etapa 1 serão forçosamente mal classificados na etapa 2. Isto é um *trade-off* intrínseco da arquitetura cascata.

# %%
def pipeline_predict(texts, tfidf1_word, tfidf1_char, net1,
                      tfidf2, net2, classes1, classes2):
    """
    Pipeline D&C: aplica net1 (Human vs IA) e, se IA, aplica net2 (qual IA?).
    Usa features combinadas (word + char) para o Modelo 1.
    """
    texts_list = list(texts) if isinstance(texts, pd.Series) else texts

    # Etapa 1: features combinadas para Modelo 1
    X1_w = tfidf1_word.transform(texts_list).toarray()
    X1_c = tfidf1_char.transform(texts_list).toarray()
    X1_tfidf = np.hstack([X1_w, X1_c])
    dummy_y1 = np.zeros((len(X1_tfidf), len(classes1)))
    probs1   = net1.predict(TextDataset(X1_tfidf, dummy_y1))
    preds1   = [classes1[np.argmax(p)] for p in probs1]

    # Etapa 2: batch de todos os textos classificados como IA
    ia_indices = [i for i, c in enumerate(preds1) if c != 'Human']
    ia_preds2 = {}
    if ia_indices:
        ia_texts = [texts_list[i] for i in ia_indices]
        X2_tfidf = tfidf2.transform(ia_texts).toarray()
        dummy_y2 = np.zeros((len(X2_tfidf), len(classes2)))
        probs2   = net2.predict(TextDataset(X2_tfidf, dummy_y2))
        for local_i, global_i in enumerate(ia_indices):
            ia_preds2[global_i] = classes2[np.argmax(probs2[local_i])]

    return [
        'Human' if preds1[i] == 'Human' else ia_preds2[i]
        for i in range(len(preds1))
    ]

# %% [markdown]
# ## 5. Avaliação Global
#
# ### 5.1 Teste Interno (amostra do dataset de treino)

# %%
# CORREÇÃO: usar uma amostra estratificada e reprodutível do dataset original
# (não retirar aleatoriamente sem estratificação — pode criar distribuições desiguais)
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=101)
for _, test_idx in sss.split(df['Text'], df['Label']):
    df_test_eval = df.iloc[test_idx]

X_eval = df_test_eval['Text']
y_eval = df_test_eval['Label']

print("Distribuição do conjunto de avaliação interna:")
print(y_eval.value_counts())

print("\nA calcular previsões do pipeline...")
preds_eval = pipeline_predict(X_eval, tfidf1_word, tfidf1_char, net1, tfidf2, net2, classes1, classes2)

all_classes = sorted(df['Label'].unique())

acc_global = accuracy_score(y_eval, preds_eval)
mcc_global = matthews_corrcoef(y_eval, preds_eval)
print(f"\nAccuracy Global (Teste Interno): {acc_global*100:.2f}%")
print(f"MCC Global (Teste Interno):      {mcc_global:.4f}")
print("\nRelatório de Classificação:")
print(classification_report(y_eval, preds_eval, labels=all_classes))

cm = confusion_matrix(y_eval, preds_eval, labels=all_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=all_classes, yticklabels=all_classes)
plt.title('Matriz de Confusão — Pipeline D&C (Teste Interno)')
plt.ylabel('Classe Real')
plt.xlabel('Previsão')
plt.tight_layout()
plt.show()
# Out:
# Distribuição do conjunto de avaliação interna:
# Label
# OpenAI       150
# Human        150
# Meta         150
# Google       150
# Anthropic    102
# Name: count, dtype: int64
#
# A calcular previsões do pipeline...
#
# Accuracy Global (Teste Interno): 90.03%
# MCC Global (Teste Interno):      0.8756
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#    Anthropic       0.91      0.94      0.93       102
#       Google       0.93      0.95      0.94       150
#        Human       0.91      0.77      0.83       150
#         Meta       0.90      0.93      0.91       150
#       OpenAI       0.85      0.93      0.89       150
#
#     accuracy                           0.90       702
#    macro avg       0.90      0.90      0.90       702
# weighted avg       0.90      0.90      0.90       702

# %% [markdown]
# ### 5.2 Avaliação no Dataset do Professor

# %%
X_ex = df_exemplos['Text']
y_ex = df_exemplos['Label']

print(f"A testar a pipeline com {len(X_ex)} exemplos do professor...")
preds_ex = pipeline_predict(X_ex, tfidf1_word, tfidf1_char, net1, tfidf2, net2, classes1, classes2)

all_classes_ex = sorted(df_exemplos['Label'].unique())

acc_ex  = accuracy_score(y_ex, preds_ex)
mcc_ex  = matthews_corrcoef(y_ex, preds_ex)
print(f"\nAccuracy (Dataset Professor): {acc_ex*100:.2f}%")
print(f"MCC (Dataset Professor):      {mcc_ex:.4f}")
print("\nRelatório de Classificação:")
print(classification_report(y_ex, preds_ex, labels=all_classes_ex))

cm_ex = confusion_matrix(y_ex, preds_ex, labels=all_classes_ex)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_ex, annot=True, fmt='d', cmap='Blues',
            xticklabels=all_classes_ex, yticklabels=all_classes_ex)
plt.title('Matriz de Confusão — Dataset do Professor')
plt.ylabel('Classe Real')
plt.xlabel('Previsão')
plt.tight_layout()
plt.show()
# Out:
# A testar a pipeline com 125 exemplos do professor...
#
# Accuracy (Dataset Professor): 52.00%
# MCC (Dataset Professor):      0.3892
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#    Anthropic       0.45      0.22      0.29        23
#       Google       0.41      0.75      0.53        16
#        Human       0.82      0.62      0.70        52
#         Meta       0.40      0.59      0.48        17
#       OpenAI       0.29      0.35      0.32        17
#
#     accuracy                           0.52       125
#    macro avg       0.47      0.50      0.46       125
# weighted avg       0.57      0.52      0.52       125

# %% [markdown]
# ### 5.3 Avaliação Intermédia: Apenas Modelo 1 (Human vs IA)

# %%
print("=" * 50)
print("AVALIAÇÃO INTERMÉDIA: MODELO 1 (HUMAN vs IA)")
print("=" * 50)

# Labels binárias do dataset do professor
y_ex_bin = np.where(df_exemplos['Label'] == 'Human', 'Human', 'IA')

# Previsões binárias via DNN1
X_ex_tfidf1 = np.hstack([
    tfidf1_word.transform(X_ex).toarray(),
    tfidf1_char.transform(X_ex).toarray()
])
dummy_y_ex1 = np.zeros((len(X_ex), len(classes1)))
ds_ex1      = TextDataset(X_ex_tfidf1, dummy_y_ex1)
probs_ex1   = net1.predict(ds_ex1)
preds_ex_bin = [classes1[np.argmax(p)] for p in probs_ex1]

acc_bin = accuracy_score(y_ex_bin, preds_ex_bin)
mcc_bin = matthews_corrcoef(y_ex_bin, preds_ex_bin)
print(f"Accuracy Binária: {acc_bin*100:.2f}% | MCC: {mcc_bin:.4f}")
print("\nRelatório de Classificação Binário:")
print(classification_report(y_ex_bin, preds_ex_bin))

cm_bin = confusion_matrix(y_ex_bin, preds_ex_bin, labels=['Human', 'IA'])
plt.figure(figsize=(5, 4))
sns.heatmap(cm_bin, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Human', 'IA'], yticklabels=['Human', 'IA'])
plt.title('Matriz de Confusão — Human vs IA (Dataset Professor)')
plt.ylabel('Classe Real')
plt.xlabel('Previsão')
plt.tight_layout()
plt.show()
# Out:
# ==================================================
# AVALIAÇÃO INTERMÉDIA: MODELO 1 (HUMAN vs IA)
# ==================================================
# Accuracy Binária: 78.40% | MCC: 0.5527
#
# Relatório de Classificação Binário:
#               precision    recall  f1-score   support
#
#        Human       0.82      0.62      0.70        52
#           IA       0.77      0.90      0.83        73
#
#     accuracy                           0.78       125
#    macro avg       0.79      0.76      0.77       125
# weighted avg       0.79      0.78      0.78       125

# %% [markdown]
# ## 6. Resumo Comparativo de Modelos

# %%
# Avaliação dos baselines no dataset do professor (para comparação)
# Baseline 1 (binário)
# Recompute ds_ex1 with combined features
X_ex_tfidf1_combined = np.hstack([
    tfidf1_word.transform(X_ex).toarray(),
    tfidf1_char.transform(X_ex).toarray()
])
dummy_y_ex1_new = np.zeros((len(X_ex), len(classes1)))
ds_ex1_new = TextDataset(X_ex_tfidf1_combined, dummy_y_ex1_new)
probs_base1_ex = baseline1.predict(ds_ex1_new)
preds_base1_ex_bin = [classes1[np.argmax(p)] for p in probs_base1_ex]
acc_base1_bin  = accuracy_score(y_ex_bin, preds_base1_ex_bin)
mcc_base1_bin  = matthews_corrcoef(y_ex_bin, preds_base1_ex_bin)

# Baseline 2 (multiclasse IAs)
df_ex_ia  = df_exemplos[df_exemplos['Label'] != 'Human']
X_ex_ia   = df_ex_ia['Text']
y_ex_ia   = df_ex_ia['Label']
X_ex_ia_tfidf2 = tfidf2.transform(X_ex_ia).toarray()
dummy_y_ex2    = np.zeros((len(X_ex_ia), len(classes2)))
probs_base2_ex = baseline2.predict(TextDataset(X_ex_ia_tfidf2, dummy_y_ex2))
preds_base2_ex = [classes2[np.argmax(p)] for p in probs_base2_ex]
acc_base2_ia   = accuracy_score(y_ex_ia, preds_base2_ex)
mcc_base2_ia   = matthews_corrcoef(y_ex_ia, preds_base2_ex)

# DNN2 (multiclasse IAs)
probs_net2_ex  = net2.predict(TextDataset(X_ex_ia_tfidf2, dummy_y_ex2))
preds_net2_ex  = [classes2[np.argmax(p)] for p in probs_net2_ex]
acc_net2_ia    = accuracy_score(y_ex_ia, preds_net2_ex)
mcc_net2_ia    = matthews_corrcoef(y_ex_ia, preds_net2_ex)

# Pipeline completo já calculado acima: acc_ex, mcc_ex

results = {
    'Modelo': [
        'Baseline 1 (Human vs IA)',
        'DNN 1 (Human vs IA)',
        'Baseline 2 (IAs)',
        'DNN 2 (IAs)',
        'Pipeline D&C (Global)',
    ],
    'Accuracy (%)': [
        f"{acc_base1_bin*100:.2f}",
        f"{acc_bin*100:.2f}",
        f"{acc_base2_ia*100:.2f}",
        f"{acc_net2_ia*100:.2f}",
        f"{acc_ex*100:.2f}",
    ],
    'MCC': [
        f"{mcc_base1_bin:.4f}",
        f"{mcc_bin:.4f}",
        f"{mcc_base2_ia:.4f}",
        f"{mcc_net2_ia:.4f}",
        f"{mcc_ex:.4f}",
    ],
    'Dataset': [
        'Professor', 'Professor', 'Professor (IAs)', 'Professor (IAs)', 'Professor'
    ]
}

df_results = pd.DataFrame(results)
print("\n=== RESUMO FINAL ===")
print(df_results.to_string(index=False))
# Out:
# === RESUMO FINAL ===
#                   Modelo Accuracy (%)    MCC         Dataset
# Baseline 1 (Human vs IA)        79.20 0.5679       Professor
#      DNN 1 (Human vs IA)        78.40 0.5527       Professor
#         Baseline 2 (IAs)        41.10 0.2317 Professor (IAs)
#              DNN 2 (IAs)        49.32 0.3539 Professor (IAs)
#    Pipeline D&C (Global)        52.00 0.3892       Professor
